# %%
#load libraries
from pandas import read_csv
from pandas.plotting import scatter_matrix

# %%
import pandas as pd

# Correct path to your iris.csv file
filename = "../../Data/coding practice/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(filename, names=names)

# %%
# show dimensions of dataset
print(dataset.shape)
# Out:
# (151, 5)

# %%
# take a peak at the dataset
print(dataset.head(20))
# Out:
#     sepal-length  sepal-width  petal-length  petal-width    class
# 0   sepal.length  sepal.width  petal.length  petal.width  variety
# 1            5.1          3.5           1.4           .2   Setosa
# 2            4.9            3           1.4           .2   Setosa
# 3            4.7          3.2           1.3           .2   Setosa
# 4            4.6          3.1           1.5           .2   Setosa
# 5              5          3.6           1.4           .2   Setosa
# 6            5.4          3.9           1.7           .4   Setosa
# 7            4.6          3.4           1.4           .3   Setosa
# 8              5          3.4           1.5           .2   Setosa
# 9            4.4          2.9           1.4           .2   Setosa
# 10           4.9          3.1           1.5           .1   Setosa
# 11           5.4          3.7           1.5           .2   Setosa
# 12           4.8          3.4           1.6           .2   Setosa
# ...

# %%
# obtain count, mean, min, max, and percentiles 
print(dataset.describe())
# Out:
#        sepal-length sepal-width petal-length petal-width   class
# count           151         151          151         151     151
# unique           36          24           44          23       4
# top               5           3          1.4          .2  Setosa
# freq             10          26           13          29      50

# %%
# look at number of rows 
print(dataset.groupby('class').size())
# Out:
# class
# Setosa        50
# Versicolor    50
# Virginica     50
# variety        1
# dtype: int64

# %%
import matplotlib.pyplot as pyplot
import pandas as pd
# make a box plot
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 import pandas as pd
#       3 # make a box plot
# ----> 4 dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
#       5 pyplot.show()
#
# File c:\Users\jpodichetty\Anaconda3\envs\iRI_25_AS\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\jpodichetty\Anaconda3\envs\iRI_25_AS\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
# ...

# %%
#make a histogram
dataset.hist()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #make a histogram
# ----> 2 dataset.hist()
#       3 pyplot.show()
#
# File c:\Users\jpodichetty\Anaconda3\envs\iRI_25_AS\Lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)    248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
# ...

# %%
#make a scatterplot
scatter_matrix(dataset)
pyplot.show()

# %%
from sklearn.model_selection import train_test_split
#splitting data into test and train
array = dataset.values
X = array[:,0:4]
y = array[:,4]
X_train, X_validaiton, y_train, y_validation = train_test_split(X,y,test_size=0.20,random_state=1)

# %%
X = array[:,0:4]
print(X)
y = array[:,4]
print(y)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
#import models for sklearn
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# spot check algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))

#evaluate each model 
results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    print('%s: %f(%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# c:\Users\aws_1\anaconda.python.official\envs\iRI_2025_AS\Lib\site-packages\sklearn\linear_model\_logistic.py:1273: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\aws_1\anaconda.python.official\envs\iRI_2025_AS\Lib\site-packages\sklearn\linear_model\_logistic.py:1288: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.svm import SVC

# Finalize the model (SVM had best predicted accuracy)
model = SVC(gamma='auto')
model.fit(X_train, y_train)

# Make predictions on validation dataset
predictions = model.predict(X_validaiton)

# Evaluate predictions
print("Accuracy:", accuracy_score(y_validation, predictions))
print("\nConfusion Matrix:\n", confusion_matrix(y_validation, predictions))
print("\nClassification Report:\n", classification_report(y_validation, predictions))# Finalize the model (SVM had best accuracy)
model = SVC(gamma='auto')
model.fit(X_train, y_train)

# Make predictions on validation dataset
predictions = model.predict(X_validaiton)

# Now print evaluation results
print("Accuracy:", accuracy_score(y_validation, predictions))
print("\nConfusion Matrix:\n", confusion_matrix(y_validation, predictions))
print("\nClassification Report:\n", classification_report(y_validation, predictions))
# Out:
# Accuracy: 0.9666666666666667
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
#
# Accuracy: 0.9666666666666667
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
# ...
